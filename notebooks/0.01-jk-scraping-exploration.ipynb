# %% [markdown]
# # Scraping exploration

# %% [markdown]
# Tailor scraping commands to extract desired information

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import json
import re

# %%
# Get html
r = requests.get('https://www.dgcoursereview.com/course.php?id=1')
soup = BeautifulSoup(r.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="has-no-js template-dg_course_view" data-app="public" data-container-key="" data-content-key="" data-cookie-prefix="xf_" data-csrf="1723640587,3413215958cc2229644f25dedc5fbf42" data-logged-in="false" data-template="dg_course_view" dir="LTR" id="XF" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
# <title>Prompton State Park | Disc Golf Course Review</title>
# <link href="/webmanifest.php" rel="manifest"/>
# <meta content="DGCR" name="apple-mobile-web-app-title"/>
# <link href="https://cdn.dgcoursereview.com/data/assets/logo/dgcr-icon-192.png" rel="apple-touch-icon"/>
# <meta content="Prompton State Park" property="og:title">
# <meta content="Prompton State Park" property="twitter:title">
# <meta content="A very scenic, mostly open course overlooking Prompton Lake with considerable elevation changes.  Each hole has 2 baskets, yellows are short, reds are long..." name="description"/>
# <meta content="A very scenic, mostly open course overlooking Prompton Lake with considerable elevation changes.  Each hole has 2 baskets, yellows are short, reds are long. The lake comes into play on three holes as well." property="og:description"/>
# <meta content="A very scenic, mostly open course overlooking Prompton Lake with considerable elevation changes.  Each hole has 2 baskets, yellows are short, reds are long. The lake comes into play on three holes..." property="twitter:description"/>
# <meta content="https://www.dgcoursereview.com/courses/prompton-state-park.1" property="og:url"/>
# <link href="https://www.dgcoursereview.com/courses/prompton-state-park.1" rel="canonical">
# <meta content="https://cdn.dgcoursereview.com/data/attach/77/77581-74568552.jpg" property="og:image"/>
# <meta content="https://cdn.dgcoursereview.com/data/attach/77/77581-74568552.jpg" property="twitter:image"/>
# <meta content="summary" property="twitter:card"/>
# <meta content="Disc Golf Course Review" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <script>
# 	var userId = 0;
# 	var currentUserLat = 40.38;
# 	var currentUserLng = -75.2718;
# 	var isManualLocation = 0;
# 	var allowLocationAccess = true;
# </script>
# <link as="font" crossorigin="anonymous" href="/styles/fonts/fa/fa-regular-400.woff2?_v=5.15.3" rel="preload" type="font/woff2">
# <link as="font" crossorigin="anonymous" href="/styles/fonts/fa/fa-solid-900.woff2?_v=5.15.3" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/styles/fonts/fa/fa-brands-400.woff2?_v=5.15.3" rel="preload" type="font/woff2"/>
# <link href="https://cdn.dgcoursereview.com/data/css/d0e81a7b95748053718c3a37c5d1a68e.css" rel="stylesheet"/>
# <link href="https://cdn.dgcoursereview.com/data/css/4a516f1d346db0f72f74a6c785ec573c.css" rel="stylesheet"/>
# <script src="/js/xf/preamble.min.js?_v=32f1f1e5"></script>
# <script>
#
#     console.log('dg_head');
#
#     let appearance;
# 	let fontSize;
#
# 	// check if cookie set with user selected apperance and font size
# 	let savedAppearance = getCookie('appearance');
# 	let savedFontSize = getCookie('fontSize');
#
# 	// set appearance and fontSize based on set or missing cookie
# 	if(savedAppearance) {
# 		appearance = savedAppearance === 'isDark' ? 'is-dark' : 'is-light';
# 	} else {
# 		appearance = window.matchMedia('(prefers-color-scheme: dark)').matches ? 'is-dark' : 'is-light';
# 	}
# 	if(savedFontSize) {
# 		fontSize = `font-size-${savedFontSize}`;
# 	} else {
# 		savedFontSize = 'default';
# 		fontSize = 'font-size-default';
# 	}
#
# 	// add appearance and font size body class
# 	document.querySelector('html').classList.add(appearance, fontSize);
#
# 	// read cookie support
# 	function getCookie (name) {
# 		let value = `; ${document.cookie}`;
# 		let parts = value.split(`; ${name}=`);
# 		if (parts.length === 2) return parts.pop().split(';').shift();
# 	}
#
# </script>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Source+Sans+Pro:ital,wght@0,400;0,600;0,700;1,400;1,700&amp;display=swap" rel="stylesheet"/>
# <link href="https://cdn.dgcoursereview.com/data/assets/logo/dgcr-icon-32.png" rel="icon" sizes="32x32" type="image/png">
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-X8MEY8H05W"></script>
# <script>
# 		window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments)}gtag("js",new Date);gtag('config','G-X8MEY8H05W',{'style_id':2,'user_properties': {
#
# 		'pwa':navigator.standalone||window.matchMedia('(display-mode: standalone), (display-mode: minimal-ui)').matches?1:0,'user_group_id':1,
# 		},});
# !function(b,c){"object"==typeof console&&"function"==typeof console.error&&(console.error_old=console.error,console.error=function(){console.error_old.apply(this,arguments);b.gtag("event","exception",{error_type:"console",error_message:arguments[0],fatal:!1})});b.onerror=function(a,d,e){b.gtag("event","exception",{error_type:"javascript",error_message:a,error_location:d,error_line_number:e,fatal:!1})};b.onload=function(){c.querySelectorAll("img").forEach(a=>{a.complete&&0===a.naturalWidth&&b.gtag("event",
# "exception",{error_type:"image",error_message:"not_loaded",error_location:a.src,fatal:!1})})}}(window,document);
# 	</script>
# <script data-cfasync="false" data-no-optimize="1">
#         (function(w, d) {
#             w.adthrive = w.adthrive || {};
#             w.adthrive.cmd = w.
#                 adthrive.cmd || [];
#             w.adthrive.plugin = 'adthrive-ads-manual';
#             w.adthrive.host = 'ads.adthrive.com';var s = d.createElement('script');
#             s.async = true;
#             s.referrerpolicy='no-referrer-when-downgrade';
#             s.src = 'https://' + w.adthrive.host + '/sites/63e07b5fb94489314afd1a19/ads.min.js?referrer=' + w.encodeURIComponent(w.location.href) + '&cb=' + (Math.floor(Math.random() * 100) + 1);
#             var n = d.getElementsByTagName('script')[0];
#             n.parentNode.insertBefore(s, n);
#         })(window, document);
#     </script>
# </link></link></link></meta></meta></head>
# <body data-template="dg_course_view">
# <div class="p-pageWrapper" id="top">
# <header class="c-header" xmlns:xf="http://www.w3.org/1999/html">
# <a aria-expanded="false" aria-label="menu" class="c-header-burger navbar-burger open" data-target="siteNavigation" role="button">
# <span aria-hidden="true"></span>
# <span aria-hidden="true"></span>
# <span aria-hidden="true"></span>
# </a>
# <span class="c-header-overlay_bg" style="display: none"></span>
# <div class="c-container">
# <div class="c-header-main">
# <div class="c-logo c-header-logo">
# <a class="c-logo-a c-header-logo-a" href="/" title="DGCourseReview"></a>
# </div>
# <div class="c-header-nav">
# <nav aria-label="main navigation" class="navbar c-navbar" role="navigation">
# <div class="c-navbar-container">
# <div class="navbar-menu">
# <a aria-expanded="false" aria-label="menu" class="c-nav-burger navbar-burger close" data-target="siteNavigation" role="button">
# <span aria-hidden="true"></span>
# <span aria-hidden="true"></span>
# <span aria-hidden="true"></span>
# </a>
# <div class="c-navbar-options">
# <a class="c-header-icon_button c-header-options-mode gb-style_options-li-a gb-appearance-switch" href="javascript:"></a>
# <a class="c-header-icon_button c-header-options-size gb-style_options-button" href="javascript:">
# <i class="fas fa-text-size"></i>
# </a>
# <div class="menu gb-style_options-menu">
# <div class="menuOutsideClicker"></div>
# <div class="menu-content">
# <div class="gb-font_size-switch">
# <div class="">
# <h3 class="menu-header"><i class="fad fa-text-size"></i>Theme font size</h3>
# <a class="menu-linkRow" href="javascript:"><span class="default"><i class="far fa-window-maximize"></i>Browser default</span></a>
# <hr class="menu-separator"/>
# <a class="menu-linkRow" href="javascript:"><span class="smallest"><i class="fas fa-text"></i>Smallest</span></a>
# <a class="menu-linkRow" href="javascript:"><span class="smaller"><i class="fas fa-text"></i>Smaller</span></a>
# <a class="menu-linkRow" href="javascript:"><span class="regular"><i class="fas fa-text"></i>Regular</span></a>
# <a class="menu-linkRow" href="javascript:"><span class="larger"><i class="fas fa-text"></i>Larger</span></a>
# <a class="menu-linkRow" href="javascript:"><span class="largest"><i class="fas fa-text"></i>Largest</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <ul class="navbar-menu-ul">
# <li class="navbar-item has-dropdown is-hoverable">
# <a class="c-navbar-link" href="/courses/" title="Courses">Courses</a>
# <span class="c-navbar-link" href="/courses/" title="Courses">Courses</span>
# <div class="navbar-dropdown" style="display: none;">
# <ul class="c-navbar-dropdown-content">
# <li class="c-navbar-dropdown-col navbar-sub-item mobile">
# <a class="c-navbar-link" href="/courses/" title="Courses">Courses</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/courses/" title="Browse Courses">Browse Courses</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/courses/random" title="Random course">Random course</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/road-trips/" title="Road trips">Road trips</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="navbar-item has-dropdown is-hoverable">
# <a class="c-navbar-link" href="/discs/" title="Discs">Discs</a>
# <span class="c-navbar-link" href="/discs/" title="Discs">Discs</span>
# <div class="navbar-dropdown" style="display: none;">
# <ul class="c-navbar-dropdown-content">
# <li class="c-navbar-dropdown-col navbar-sub-item mobile">
# <a class="c-navbar-link" href="/discs/" title="Discs">Discs</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/discs/" title="Browse Discs">Browse Discs</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/user-discs/" title="Member discs">Member discs</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/user-discs/wanted" title="Wanted Discs">Wanted Discs</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/user-discs/tradable" title="Tradable Discs">Tradable Discs</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/forums/the-marketplace.39/" title="DGCR Marketplace">DGCR Marketplace</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/manufacturers/" title="Manufacturers">Manufacturers</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="navbar-item has-dropdown is-hoverable">
# <a class="c-navbar-link" href="/events/" title="Events">Events</a>
# <span class="c-navbar-link" href="/events/" title="Events">Events</span>
# <div class="navbar-dropdown" style="display: none;">
# <ul class="c-navbar-dropdown-content">
# <li class="c-navbar-dropdown-col navbar-sub-item mobile">
# <a class="c-navbar-link" href="/events/" title="Events">Events</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/events/month/" title="Monthly">Monthly</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/events/week/" title="Weekly">Weekly</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/events/events/" title="Agenda">Agenda</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/events/archive/" title="Archive">Archive</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="navbar-item has-dropdown is-hoverable">
# <a class="c-navbar-link" href="/forums/" title="Forums">Forums</a>
# <span class="c-navbar-link" href="/forums/" title="Forums">Forums</span>
# <div class="navbar-dropdown" style="display: none;">
# <ul class="c-navbar-dropdown-content">
# <li class="c-navbar-dropdown-col navbar-sub-item mobile">
# <a class="c-navbar-link" href="/forums/" title="Forums">Forums</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/whats-new/posts/" title="New posts">New posts</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/media/" title="Media">Media</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="navbar-item has-dropdown is-hoverable">
# <a class="c-navbar-link" href="/whats-new/" title="What's new">What's new</a>
# <span class="c-navbar-link" href="/whats-new/" title="What's new">What's new</span>
# <div class="navbar-dropdown" style="display: none;">
# <ul class="c-navbar-dropdown-content">
# <li class="c-navbar-dropdown-col navbar-sub-item mobile">
# <a class="c-navbar-link" href="/whats-new/" title="What's new">What's new</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/whats-new/reviews/" title="New reviews">New reviews</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/whats-new/courses/" title="New courses">New courses</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/whats-new/posts/" title="New posts">New posts</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/whats-new/media/" title="New media">New media</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/whats-new/latest-activity" title="Latest activity">Latest activity</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="navbar-item has-dropdown is-hoverable">
# <a class="c-navbar-link" href="/members/" title="Members">Members</a>
# <span class="c-navbar-link" href="/members/" title="Members">Members</span>
# <div class="navbar-dropdown" style="display: none;">
# <ul class="c-navbar-dropdown-content">
# <li class="c-navbar-dropdown-col navbar-sub-item mobile">
# <a class="c-navbar-link" href="/members/" title="Members">Members</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/online/" title="Current visitors">Current visitors</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/whats-new/profile-posts/" title="New profile posts">New profile posts</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/search/?type=profile_post" title="Search profile posts">Search profile posts</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/courses/trusted-reviewers" title="Trusted reviewers">Trusted reviewers</a>
# </li>
# <li class="c-navbar-dropdown-col navbar-sub-item">
# <a class="c-navbar-link" href="/achievements/leaderboard" title="Achievements leaderboard">Achievements leaderboard</a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <span id="c-navbar_close" style="display: none;"></span>
# </nav>
# </div>
# <div class="c-header-opposite">
# <div class="c-header-options _search">
# <a aria-expanded="false" aria-haspopup="true" aria-label="Search" class="c-header-icon_button c-header-options-search" data-xf-click="menu" data-xf-key="/" href="/search/" title="Search">
# <i class="fas fa-search"></i>
# <span>Search</span>
# </a>
# <div aria-hidden="true" class="menu menu--structural menu--wide" data-menu="menu">
# <form action="/search/search" class="menu-content" data-xf-init="quick-search" method="post">
# <h3 class="menu-header">Search</h3>
# <div class="menu-row">
# <div class="inputGroup inputGroup--joined">
# <input aria-label="Search" class="input" data-menu-autofocus="true" name="keywords" placeholder="Search…" type="text"/>
# <select aria-label="Search within" class="js-quickSearch-constraint input" name="constraints">
# <option value="">Everywhere</option>
# <option value='{"search_type":"dg_course"}'>Courses</option>
# <option value='{"search_type":"dg_course_review"}'>Reviews</option>
# <option value='{"search_type":"dg_course_review","c":{"course":1}}'>This course</option>
# </select>
# </div>
# </div>
# <div class="menu-row">
# <label class="iconic"><input name="c[title_only]" type="checkbox" value="1"/><i aria-hidden="true"></i><span class="iconic-label">Search titles only</span></label>
# </div>
# <div class="menu-row">
# <div class="inputGroup">
# <span class="inputGroup-text" id="ctrl_search_menu_by_member">By:</span>
# <input aria-labelledby="ctrl_search_menu_by_member" class="input" data-xf-init="auto-complete" name="c[users]" placeholder="Member" type="text"/>
# </div>
# </div>
# <div class="menu-footer">
# <span class="menu-footer-controls">
# <button class="button--primary button button--icon button--icon--search" type="submit"><span class="button-text">Search</span></button>
# <a class="button" href="/search/"><span class="button-text">Advanced search…</span></a>
# </span>
# </div>
# <input name="_xfToken" type="hidden" value="1723640587,3413215958cc2229644f25dedc5fbf42"/>
# </form>
# </div>
# </div>
# <div class="c-header-spacer"><span></span></div>
# <div class="c-header-options _style">
# <a class="c-header-icon_button c-header-options-mode gb-style_options-li-a gb-appearance-switch" href="javascript:"></a>
# <a class="c-header-icon_button c-header-options-size gb-style_options-button" href="javascript:">
# <i class="fas fa-text-size"></i>
# </a>
# <div class="menu gb-style_options-menu">
# <div class="menuOutsideClicker"></div>
# <div class="menu-content">
# <div class="gb-font_size-switch">
# <div class="">
# <h3 class="menu-header"><i class="fad fa-text-size"></i>Theme font size</h3>
# <a class="menu-linkRow" href="javascript:"><span class="default"><i class="far fa-window-maximize"></i>Browser default</span></a>
# <hr class="menu-separator"/>
# <a class="menu-linkRow" href="javascript:"><span class="smallest"><i class="fas fa-text"></i>Smallest</span></a>
# <a class="menu-linkRow" href="javascript:"><span class="smaller"><i class="fas fa-text"></i>Smaller</span></a>
# <a class="menu-linkRow" href="javascript:"><span class="regular"><i class="fas fa-text"></i>Regular</span></a>
# <a class="menu-linkRow" href="javascript:"><span class="larger"><i class="fas fa-text"></i>Larger</span></a>
# <a class="menu-linkRow" href="javascript:"><span class="largest"><i class="fas fa-text"></i>Largest</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="c-header-spacer"><span></span></div>
# <div class="c-header-user c-header-user--guest">
# <a class="p-navgroup-link p-navgroup-link--textual p-navgroup-link--logIn" data-follow-redirects="on" data-xf-click="overlay" href="/login/">
# <span class="p-navgroup-linkText">Log in</span>
# </a>
# <a class="p-navgroup-link p-navgroup-link--textual p-navgroup-link--register" data-follow-redirects="on" data-xf-click="overlay" href="/login/register">
# <span class="p-navgroup-linkText">Register</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="p-body">
# <div class="p-body-inner">
# <ul class="notices notices--block js-notices" data-scroll-interval="6" data-type="block" data-xf-init="notices">
# <li class="notice js-notice notice--accent" data-auto-dismiss="" data-delay-duration="0" data-display-duration="0" data-notice-id="10" data-visibility="">
# <div class="notice-content">
# <a class="notice-dismiss js-noticeDismiss" data-xf-init="tooltip" href="/account/dismiss-notice?notice_id=10" title="Dismiss notice"></a>
# <p>Discover new ways to elevate your game with the updated DGCourseReview app! <br/>It's entirely free and enhanced with features shaped by user feedback to ensure your best experience on the course. (<a href="https://apps.apple.com/us/app/disc-golf-course-review/id1029793833?ls=1">App Store</a> or <a href="https://play.google.com/store/apps/details?id=com.dgcoursereview.android">Google Play</a>)</p>
# </div>
# </li>
# </ul>
# <ul class="p-breadcrumbs" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a href="/courses/" itemprop="item">
# <span itemprop="name">Courses</span>
# </a>
# <meta content="1" itemprop="position"/>
# </li>
# </ul>
# <noscript class="js-jsWarning"><div class="blockMessage blockMessage--important blockMessage--iconic u-noJsOnly">JavaScript is disabled. For a better experience, please enable JavaScript in your browser before proceeding.</div></noscript>
# <div class="blockMessage blockMessage--important blockMessage--iconic js-browserWarning" style="display: none">You are using an out of date browser. It may not display this or other websites correctly.<br>You should upgrade or use an <a href="https://www.google.com/chrome/" rel="noopener" target="_blank">alternative browser</a>.</br></div>
# <div class="c-subnav">
# <div class="c-subnav-navigation">
# <div class="hScroller" data-auto-scroll=".p-navEl.is-selected" data-xf-init="h-scroller">
# <div class="hScroller-scroll">
# <div class="">
# <ul class="c-subnav-ul">
# <li class="c-subnav-li">
# <div class="p-navEl">
# <a class="p-navEl-link" data-nav-id="browse_courses" data-xf-key="alt+1" href="/courses/">Browse Courses</a>
# </div>
# </li>
# <li class="c-subnav-li">
# <div class="p-navEl">
# <a class="p-navEl-link" data-nav-id="random_course" data-xf-key="alt+2" href="/courses/random">Random course</a>
# </div>
# </li>
# <li class="c-subnav-li">
# <div class="p-navEl">
# <a class="p-navEl-link" data-nav-id="roadTrip" data-xf-key="alt+3" href="/road-trips/">Road trips</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="c-subnav-actions">
# <a class="button--cta button button--icon button--icon--edit" data-xf-click="overlay" href="/courses/prompton-state-park.1/edit"><span class="button-text">Update info</span></a>
# <a class="button" data-href="/courses/prompton-state-park.1/share" data-xf-init="share-tooltip" target="_blank" title="Share Course">
# <i class="fas fa-share-alt"></i>
# </a>
# </div>
# </div>
# <div class="p-body-main p-body-main--withSidebar">
# <div class="p-body-contentCol"></div>
# <div class="p-body-sidebarCol"></div>
# <div class="p-body-content">
# <div class="gb-sponsored-wrapper">
# </div>
# <div class="p-body-pageContent">
# <div class="dg-course-above-full">
# </div>
# <div class="dg-course-above-split dg-course-widgets-split">
# </div>
# <div class="c-course">
# <div class="c-course-header">
# <div class="c-course-info">
# <span class="c-course-info-location">Honesdale,
# <a href="/courses/state/pennsylvania.45/" title="Browse courses in Pennsylvania">PA</a>
# </span>
# <h1 class="c-course-info-title">Prompton State Park</h1>
# <div class="c-course-info-details">
# <span class="c-course-info-type">Permanent course</span>
# </div>
# </div>
# <div class="c-course-header-group">
# <div class="c-course-header-row">
# <div class="c-course-add_to-wrapper">
# <div class="c-course-add_to">
# <a class="c-course-add_to-wishlist" data-add-text="Add to wishlist" data-qty="86" data-remove-text="Remove from wishlist" data-xf-click="dg_header_switch" href="/courses/prompton-state-park.1/wishlist" title="Add to wishlist"></a>
# </div>
# <div class="c-course-add_to">
# <a class="c-course-add_to-played" data-add-text="Mark as played" data-qty="242" data-remove-text="Unmark as played" data-xf-click="dg_header_switch" href="/courses/prompton-state-park.1/played" title="Mark as played"></a>
# </div>
# <div class="c-course-add_to">
# <a class="c-course-add_to-favourites" data-add-text="Add to favorites" data-qty="41" data-remove-text="Remove from favorites" data-xf-click="dg_header_switch" href="/courses/prompton-state-park.1/favorite" title="Add to favorites"></a>
# </div>
# </div>
# <div class="c-course-rating">
# <div class="c-course-rating-star">
# <span style="width: 79%"></span>
# </div>
# <span class="c-course-rating-value">3.95<span class="_max">5</span><span class="_total">(based on 20 reviews)</span></span>
# </div>
# </div>
# <nav class="c-course-tabs">
# <ul class="c-course-tabs-ul">
# <li class="c-course-tabs-li active">
# <a class="c-course-tabs-li-a" href="/courses/prompton-state-park.1" title="Course Info">Info</a>
# </li>
# <li class="c-course-tabs-li">
# <a class="c-course-tabs-li-a" href="/courses/prompton-state-park.1/holes" title="Holes">Holes</a>
# </li>
# <li class="c-course-tabs-li">
# <a class="c-course-tabs-li-a _with_qty" href="/courses/prompton-state-park.1/media" title="Media">Media<span class="_qty" data-qty="90"></span></a>
# </li>
# <li class="c-course-tabs-li">
# <a class="c-course-tabs-li-a _with_qty" href="/threads/prompton-state-park-discussion.1/" title="Discussion">Discussion<span class="_qty" data-qty="0"></span></a>
# </li>
# <li class="c-course-tabs-li">
# <a class="c-course-tabs-li-a _with_qty" href="/courses/prompton-state-park.1/reviews" title="Reviews">Reviews<span class="_qty" data-qty="20"></span></a>
# </li>
# <li class="c-course-tabs-li">
# <a class="c-course-tabs-li-a" href="/courses/prompton-state-park.1/users" title="Users">Users</a>
# </li>
# <li class="c-course-tabs-li">
# <a class="c-course-tabs-li-a" href="/courses/prompton-state-park.1/stats" title="Stats">Stats</a>
# </li>
# <li class="c-course-tabs-li">
# <a class="c-course-tabs-li-a _with_qty" href="/courses/prompton-state-park.1/rounds" title="Rounds">Rounds<span class="_qty" data-qty="101"></span></a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <div class="c-course-course_info">
# <div class="c-course-body c-course-body-info">
# <div class="c-course-main">
# <div class="c-course-highlights">
# <div class="c-course-stats">
# <div class="c-course-stat">
# <span class="c-course-stat-label"><span class="dg_unit" data-current-units="ft" data-feet="5864" data-meters="1787">5864 ft</span>. - <span class="dg_unit" data-current-units="ft" data-feet="8071" data-meters="2460">8071 ft</span>. <a class="c-micro_button unit_switch" data-xf-click="unit_switch">Metric</a></span>
# </div>
# <div class="c-course-stat">
# <span class="c-course-stat-label">Moderately Hilly</span>
# </div>
# <div class="c-course-stat">
# <span class="c-course-stat-label">Lightly Wooded</span>
# </div>
# <div class="c-course-stat">
# <span class="c-course-stat-val _holes">18</span>
# <span class="c-course-stat-label">Holes</span>
# </div>
# <div class="c-course-stat">
# <span class="c-course-stat-val _baskets">18</span>
# <span class="c-course-stat-label">Baskets</span>
# </div>
# <div class="c-course-stat">
# <span class="c-course-stat-val _water">5</span>
# <span class="c-course-stat-label">Water in play</span>
# </div>
# </div>
# </div>
# <div class="c-course-updates">
# <div class="c-course-updates-content">
# <h2>Prompton State Park</h2>
# <div class="c-course-conditions">
# <div class="c-course-conditions-status">
# <h3>Course conditions:</h3>
# <ul>
# <li class=""><span>Unplayable</span></li>
# <li class=""><span>Bad</span></li>
# <li class=""><span>Decent</span></li>
# <li class=""><span>Good</span></li>
# <li class=""><span>Perfect</span></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="c-course-updates-footer">
# <div class="hScroller" data-xf-init="h-scroller">
# <div class="hScroller-scroll">
# <div class="buttonGroup">
# <a class="button" data-xf-click="overlay" href="/courses/prompton-state-park.1/update-conditions" title="Update course conditions">Update
# conditions</a>
# <a class="button" data-xf-click="overlay" href="/courses/prompton-state-park.1/add-news" title="Add course news">Add news</a>
# <a class="button" data-xf-click="overlay" href="/courses/prompton-state-park.1/add-tournament" title="Add course tournament">Add tournament</a>
# <a class="button" data-xf-click="overlay" href="/courses/prompton-state-park.1/add-event" title="Add course regular event">Add event</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="c-course-description">
# <p><div class="bbWrapper">A very scenic, mostly open course overlooking Prompton Lake with considerable elevation changes. Each hole has 2 baskets, yellows are short, reds are long. The lake comes into play on three holes as well.</div></p>
# </div>
# <div class="c-course-details">
# <div class="c-course-details-row">
# <span>Designer(s): </span>
# <span>John Harvey Dave Harvey</span>
# </div>
# <div class="c-course-details-row">
# <span>Year established:</span>
# <span>1997</span>
# </div>
# <div class="c-course-details-row">
# <span>Multiple Tees / Pins:</span>
# <span>No / Yes</span>
# </div>
# <div class="c-course-details-row">
# <span>Par Info:</span>
# <span>
# <span class="c-bullet">
# <span class="c-bullet-icon" style="background-color:#FFFF00;"></span>
# 57
# </span>
# <span class="c-bullet">
# <span class="c-bullet-icon" style="background-color:#FF0000;"></span>
# 67
# </span>
# </span>
# </div>
# <div class="c-course-details-row">
# <span>DGCR SSE: [ <a data-xf-click="overlay" href="/courses/sse-help">?</a> ]</span>
# <span>
# <span class="c-bullet">
# <span class="c-bullet-icon" style="background-color:#FFFF00;"></span>
# 46.8
# </span>
# <span class="c-bullet">
# <span class="c-bullet-icon" style="background-color:#FF0000;"></span>
# 54.3
# </span>
# </span>
# </div>
# <div class="c-course-details-row">
# <span>Rounds Recorded / Average Score:</span>
# <span>
# <a href="/courses/prompton-state-park.1/rounds">101 / 62</a>
# <span class="c-bullet"><span class="c-bullet-icon" style="background-color:#FFFF00;"></span>77 / 60</span>
# <span class="c-bullet"><span class="c-bullet-icon" style="background-color:#FF0000;"></span>20 / 67</span>
# </span>
# </div>
# <div class="c-course-details-row">
# <span>Tee Type:</span>
# <span>Concrete</span>
# </div>
# <div class="c-course-details-row">
# <span>Hole Type:</span>
# <span>DISCatcher</span>
# </div>
# <div class="c-course-details-row">
# <span>Discs lost:</span>
# <span><a href="/courses/prompton-state-park.1/lost-discs">4</a></span>
# </div>
# <div class="c-course-details-row">
# <div class="c-course-details-row _misc_info">
# <span class="_label">Misc. info.:</span>
# <div class="_group">
# <span class="_item _camping">Camping nearby</span>
# <span class="_item _cartfriendly">Somewhat cart friendly</span>
# </div>
# </div>
# </div>
# </div>
# <div class="c-course-links" id="course_links">
# <div class="_header">
# <h3><i class="fas fa-globe-americas"></i>Links and files</h3>
# <div class="_add">
# <a class="muted" data-xf-click="overlay" href="/courses/prompton-state-park.1/add-link"><i class="fas fa-plus-circle"></i><span>Add link</span></a>
# <a class="muted" data-xf-click="overlay" href="/courses/prompton-state-park.1/add-file"><i class="fas fa-plus-circle"></i><span>Add file</span></a>
# <a class="muted" data-xf-click="overlay" href="/courses/prompton-state-park.1/list-files"><span>
# <i class="fas fa-exclamation-triangle"></i><span>Report</span>
# </span></a>
# </div>
# </div>
# <ul>
# <li>
# <a href="/courses/prompton-state-park.1/scorecards" target="_blank"><i class="fas fa-print"></i>Print Scorecard (All Tees)</a>
# </li>
# <li>
# <a href="/courses/prompton-state-park.1/print" target="_blank"><i class="fas fa-print"></i>Print Course</a>
# </li>
# <li>
# <a href="http://www.dcnr.state.pa.us/stateparks/findapark/prompton/index.htm" rel="nofollow ugc" target="_blank"><i class="fas fa-link"></i>Prompton State Park Homepage<span></span></a>
# </li>
# <li>
# <a href="/attachments/234798f6-gif.218484/" rel="nofollow ugc" target="_blank"><i class="fas fa-file-image"></i>Course Map<span>(139 KB)</span></a>
# </li>
# </ul>
# </div>
# <div class="c-course-location">
# <h3>Location</h3>
# <div class="c-course-location-address">
# <span>[unknown]</span>
# <span>Honesdale, <a href="/courses/?zip=18456">18456</a></span>
# <span><a href="/courses/state/pennsylvania.45/">Pennsylvania</a> </span>
# <span></span>
# <ul>
# <li><a href="/courses/?zip=18456">Browse map by zip</a></li>
# <li><a href="https://www.google.com/maps/search/?api=1&amp;query=41.591367,-75.330167" target="_blank">Show in Google Maps</a></li>
# <li><a href="https://www.hotels.com/mobile/search.html?destination=Honesdale%2CPA+18456" rel="nofollow" target="_blank">Find nearby hotels</a></li>
# </ul>
# </div>
# <div class="c-course-location-directions">
# <span>Local Directions:</span>
# <p><div class="bbWrapper">From I-81, take Rte. 6 east, from I-84, take Rte. 6 west; then 4 miles west of Honesdale. Go north on Rte. 170, 0.4 mile make a right. 1st hole to right of parking lot.</div></p>
# </div>
# <div class="c-course-location-position">
# <span>Latitude / Longitude:</span>
# <div>
# <span>41.591367, -75.330167</span>
# <a class="c-micro_button" title="Display in Degree Notation">degree</a>
# </div>
# </div>
# </div>
# <div class="c-course-report">
# <a class="muted" data-xf-click="overlay" href="/courses/prompton-state-park.1/report"><i class="fas fa-exclamation-triangle"></i><span>Report Error/Abuse</span></a>
# </div>
# </div>
# <div class="c-course-col">
# <script class="js-extraPhrases" type="application/json">
# 			{
# 				"lightbox_close": "Close",
# 				"lightbox_next": "Next",
# 				"lightbox_previous": "Previous",
# 				"lightbox_error": "The requested content cannot be loaded. Please try again later.",
# 				"lightbox_start_slideshow": "Start slideshow",
# 				"lightbox_stop_slideshow": "Stop slideshow",
# 				"lightbox_full_screen": "Full screen",
# 				"lightbox_thumbnails": "Thumbnails",
# 				"lightbox_download": "Download",
# 				"lightbox_share": "Share",
# 				"lightbox_zoom": "Zoom",
# 				"lightbox_new_window": "New window",
# 				"lightbox_toggle_sidebar": "Toggle sidebar"
# 			}
# 			</script>
# <div class="itemList js-lbContainer c-course-col-media" data-lb-id="course_cover" data-lb-next="/courses/prompton-state-park.1/media" data-xf-init="lightbox">
# <div class="lbContainer js-lbContainer c-course-col-media-image" style="background-image: url(https://cdn.dgcoursereview.com/data/attach/77/77581-74568552.jpg)">
# <a class="js-lbImage c-course-col-media-link" data-lb-caption-desc="" data-lb-caption-href="/media/hole-16-yellow-basket-to-tee.111791/" data-lb-sidebar="1" data-lb-type-override="" data-src="https://cdn.dgcoursereview.com/data/attach/77/77581-74568552.jpg" data-type="image" href="/media/hole-16-yellow-basket-to-tee.111791/" target="_blank"></a>
# </div>
# <div class="c-course-col-media-info-wrapper">
# <div class="c-course-col-media-info">
# <div class="c-course-col-media-row _caption">
# <span>Hole #16 Yellow Basket to Tee</span>
# </div>
# <div class="c-course-col-media-row _info">
# <span class="_hole">
# Hole #16 (Taken 6/2013)
# </span>
# <span class="_author"><i class="fas fa-camera"></i><a class="username" data-user-id="1" data-xf-init="member-tooltip" dir="auto" href="/members/timg.1/"><span class="username--admin c_name">timg</span><span class="c_trusted-gold" title="Gold level trusted reviewer"></span><span class="c_premium" title="Premium member"></span></a></span>
# </div>
# <div class="c-course-col-media-row _par">
# <span class="_label">Par / Distance:</span>
# <span>
# <span class="cap"><span style="background: #FFFF00"></span>3 / 277ft.</span>
# <span class="cap"><span style="background: #FF0000"></span>4 / 383ft.</span>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="c-course-col-nearby">
# <h3>Nearby Courses</h3>
# <a class="c-course-col-nearby-map" href="/courses/?course=1"><img alt="Prompton State Park nearby courses map" src="https://cdn.dgcoursereview.com/data/static_maps/0/1-b7cefafed6b75d5ae38541f4788a281c-1704153783.jpg"/></a>
# <div class="c-course-col-nearby-row">
# <span class="c-nearby-direction _wnw" style="background-color: #3564C4;"></span>
# <a href="/courses/kennedy-park-dgc.2696">Kennedy Park DGC</a>
# <span class="c-nearby-direction-distance">8.6 Miles</span>
# </div>
# <div class="c-course-col-nearby-row">
# <span class="c-nearby-direction _ese" style="background-color: #6DC03B;"></span>
# <a href="/courses/woodloch-disc-golf.12635">Woodloch Disc Golf</a>
# <span class="c-nearby-direction-distance">13.5 Miles</span>
# </div>
# <div class="c-course-col-nearby-row">
# <span class="c-nearby-direction _nw" style="background-color: #F3DA0A;"></span>
# <a href="/courses/rock-mountain-dgc.7052">Rock Mountain DGC</a>
# <span class="c-nearby-direction-distance">19.2 Miles</span>
# </div>
# <div class="c-course-col-nearby-row">
# <span class="c-nearby-direction _wsw" style="background-color: #FF6600;"></span>
# <a href="/courses/waverly-dgc.6129">Waverly DGC</a>
# <span class="c-nearby-direction-distance">19.9 Miles</span>
# </div>
# <div class="c-course-col-nearby-row">
# <span class="c-nearby-direction _w" style="background-color: #DC0000;"></span>
# <a href="/courses/william-b-kresge-memorial-dgc.11456">William B. Kresge Memorial DGC</a>
# <span class="c-nearby-direction-distance">29.5 Miles</span>
# </div>
# <a class="c-course-col-nearby-more" href="/courses/?course=1">Find
# more nearby courses</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="p-body-sidebar">
# <div class="gb-sponsored-wrapper">
# </div>
# <div class="block" data-widget-definition="new_posts" data-widget-id="7" data-widget-key="forum_overview_new_posts">
# <div class="block-container">
# <h3 class="block-minorHeader">
# <a href="/whats-new/posts/?skip=1" rel="nofollow">Latest posts</a>
# </h3>
# <ul class="block-body">
# <li class="block-row">
# <div class="contentRow">
# <div class="contentRow-figure">
# <a class="avatar avatar--xxs" data-user-id="6739" data-xf-init="member-tooltip" href="/members/bogeynomore.6739/">
# <img alt="BogeyNoMore" class="avatar-u6739-s" height="48" loading="lazy" src="https://cdn.dgcoursereview.com/data/avatars/s/6/6739.jpg?1689403173" width="48">
# </img></a>
# </div>
# <div class="contentRow-main contentRow-main--close">
# <a href="/threads/whatsup-with-these-lonestar-sponsorships.175964/post-4264378">Whatsup with these lonestar sponsorships</a>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <ul class="listInline listInline--bullet">
# <li>Latest: BogeyNoMore</li>
# <li><time class="u-dt" data-date-string="Aug 14, 2024" data-time="1723638356" data-time-string="8:25 AM" datetime="2024-08-14T08:25:56-0400" dir="auto" title="Aug 14, 2024 at 8:25 AM">37 minutes ago</time></li>
# </ul>
# </div>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <a href="/forums/general-disc-golf-chat.7/">General Disc Golf Chat</a>
# </div>
# </div>
# </div>
# </li>
# <li class="block-row">
# <div class="contentRow">
# <div class="contentRow-figure">
# <a class="avatar avatar--xxs" data-user-id="33140" data-xf-init="member-tooltip" href="/members/andyjb.33140/">
# <img alt="AndyJB" class="avatar-u33140-s" height="48" loading="lazy" src="https://cdn.dgcoursereview.com/data/avatars/s/33/33140.jpg?1689403262" width="48"/>
# </a>
# </div>
# <div class="contentRow-main contentRow-main--close">
# <a href="/threads/my-new-book-saving-for-par-comes-out-this-month.179346/post-4264376">My new book, "Saving For Par" comes out this month!</a>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <ul class="listInline listInline--bullet">
# <li>Latest: AndyJB</li>
# <li><time class="u-dt" data-date-string="Aug 14, 2024" data-time="1723635070" data-time-string="7:31 AM" datetime="2024-08-14T07:31:10-0400" dir="auto" title="Aug 14, 2024 at 7:31 AM">Today at 7:31 AM</time></li>
# </ul>
# </div>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <a href="/forums/general-disc-golf-chat.7/">General Disc Golf Chat</a>
# </div>
# </div>
# </div>
# </li>
# <li class="block-row">
# <div class="contentRow">
# <div class="contentRow-figure">
# <a class="avatar avatar--xxs" data-user-id="77974" data-xf-init="member-tooltip" href="/members/sheep.77974/">
# <img alt="Sheep" class="avatar-u77974-s" height="48" loading="lazy" src="https://cdn.dgcoursereview.com/data/avatars/s/77/77974.jpg?1722520130" width="48"/>
# </a>
# </div>
# <div class="contentRow-main contentRow-main--close">
# <a href="/threads/mvp-disc-sports-part-vi.148784/post-4264374"><span class="label label--primary" dir="auto">[MVP]</span><span class="label-append"> </span>MVP Disc Sports (Part VI)</a>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <ul class="listInline listInline--bullet">
# <li>Latest: Sheep</li>
# <li><time class="u-dt" data-date-string="Aug 14, 2024" data-time="1723634641" data-time-string="7:24 AM" datetime="2024-08-14T07:24:01-0400" dir="auto" title="Aug 14, 2024 at 7:24 AM">Today at 7:24 AM</time></li>
# </ul>
# </div>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <a href="/forums/discs.46/">Discs</a>
# </div>
# </div>
# </div>
# </li>
# <li class="block-row">
# <div class="contentRow">
# <div class="contentRow-figure">
# <a class="avatar avatar--xxs" data-user-id="92868" data-xf-init="member-tooltip" href="/members/auzcar.92868/">
# <img alt="auzcar" class="avatar-u92868-s" height="48" loading="lazy" src="https://cdn.dgcoursereview.com/data/avatars/s/92/92868.jpg?1689443537" width="48"/>
# </a>
# </div>
# <div class="contentRow-main contentRow-main--close">
# <a href="/threads/clash-discs.147429/post-4264372"><span class="label label--primary" dir="auto">[Other]</span><span class="label-append"> </span>Clash Discs</a>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <ul class="listInline listInline--bullet">
# <li>Latest: auzcar</li>
# <li><time class="u-dt" data-date-string="Aug 14, 2024" data-time="1723632155" data-time-string="6:42 AM" datetime="2024-08-14T06:42:35-0400" dir="auto" title="Aug 14, 2024 at 6:42 AM">Today at 6:42 AM</time></li>
# </ul>
# </div>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <a href="/forums/discs.46/">Discs</a>
# </div>
# </div>
# </div>
# </li>
# <li class="block-row">
# <div class="contentRow">
# <div class="contentRow-figure">
# <a class="avatar avatar--xxs avatar--default avatar--default--dynamic" data-user-id="112904" data-xf-init="member-tooltip" href="/members/mobius27.112904/" style="background-color: #d6d65c; color: #66661a">
# <span aria-label="Mobius27" class="avatar-u112904-s" role="img">M</span>
# </a>
# </div>
# <div class="contentRow-main contentRow-main--close">
# <a href="/threads/60mph-vs-56mph.179186/post-4264371">60mph vs 56mph</a>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <ul class="listInline listInline--bullet">
# <li>Latest: Mobius27</li>
# <li><time class="u-dt" data-date-string="Aug 14, 2024" data-time="1723625601" data-time-string="4:53 AM" datetime="2024-08-14T04:53:21-0400" dir="auto" title="Aug 14, 2024 at 4:53 AM">Today at 4:53 AM</time></li>
# </ul>
# </div>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <a href="/forums/form-analysis-critique.54/">Form Analysis/Critique</a>
# </div>
# </div>
# </div>
# </li>
# <li class="block-row">
# <div class="contentRow">
# <div class="contentRow-figure">
# <a class="avatar avatar--xxs" data-user-id="35674" data-xf-init="member-tooltip" href="/members/wolfhaley.35674/">
# <img alt="wolfhaley" class="avatar-u35674-s" height="48" loading="lazy" src="https://cdn.dgcoursereview.com/data/avatars/s/35/35674.jpg?1691216919" width="48"/>
# </a>
# </div>
# <div class="contentRow-main contentRow-main--close">
# <a href="/threads/water-works-park-discussion.179367/post-4264370">Water Works Park discussion</a>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <ul class="listInline listInline--bullet">
# <li>Latest: wolfhaley</li>
# <li><time class="u-dt" data-date-string="Aug 14, 2024" data-time="1723623943" data-time-string="4:25 AM" datetime="2024-08-14T04:25:43-0400" dir="auto" title="Aug 14, 2024 at 4:25 AM">Today at 4:25 AM</time></li>
# </ul>
# </div>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <a href="/forums/course-discussions.3/">Course Discussions</a>
# </div>
# </div>
# </div>
# </li>
# <li class="block-row">
# <div class="contentRow">
# <div class="contentRow-figure">
# <a class="avatar avatar--xxs" data-user-id="2450" data-xf-init="member-tooltip" href="/members/sidewinder22.2450/">
# <img alt="sidewinder22" class="avatar-u2450-s" height="48" loading="lazy" src="https://cdn.dgcoursereview.com/data/avatars/s/2/2450.jpg?1689403157" width="48"/>
# </a>
# </div>
# <div class="contentRow-main contentRow-main--close">
# <a href="/threads/frustration-can%E2%80%99t-get-over-250ft-max-327.175751/post-4264369">Frustration can’t get over 250ft max 327</a>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <ul class="listInline listInline--bullet">
# <li>Latest: sidewinder22</li>
# <li><time class="u-dt" data-date-string="Aug 14, 2024" data-time="1723614424" data-time-string="1:47 AM" datetime="2024-08-14T01:47:04-0400" dir="auto" title="Aug 14, 2024 at 1:47 AM">Today at 1:47 AM</time></li>
# </ul>
# </div>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <a href="/forums/form-analysis-critique.54/">Form Analysis/Critique</a>
# </div>
# </div>
# </div>
# </li>
# <li class="block-row">
# <div class="contentRow">
# <div class="contentRow-figure">
# <a class="avatar avatar--xxs" data-user-id="2450" data-xf-init="member-tooltip" href="/members/sidewinder22.2450/">
# <img alt="sidewinder22" class="avatar-u2450-s" height="48" loading="lazy" src="https://cdn.dgcoursereview.com/data/avatars/s/2/2450.jpg?1689403157" width="48"/>
# </a>
# </div>
# <div class="contentRow-main contentRow-main--close">
# <a href="/threads/form-help.133292/post-4264367">Form Help.</a>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <ul class="listInline listInline--bullet">
# <li>Latest: sidewinder22</li>
# <li><time class="u-dt" data-date-string="Aug 14, 2024" data-time="1723613471" data-time-string="1:31 AM" datetime="2024-08-14T01:31:11-0400" dir="auto" title="Aug 14, 2024 at 1:31 AM">Today at 1:31 AM</time></li>
# </ul>
# </div>
# <div class="contentRow-minor contentRow-minor--hideLinks">
# <a href="/forums/form-analysis-critique.54/">Form Analysis/Critique</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <ul class="p-breadcrumbs p-breadcrumbs--bottom" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a href="/courses/" itemprop="item">
# <span itemprop="name">Courses</span>
# </a>
# <meta content="1" itemprop="position"/>
# </li>
# </ul>
# </div>
# </div>
# <footer class="c-footer" id="footer">
# <div class="c-container">
# <div class="c-footer-top">
# <div class="c-logo c-footer-logo">
# <a class="c-logo-a c-footer-logo-a" href="/" title="DGCourseReview"></a>
# </div>
# <ul class="c-footer-nav">
# <li><a href="/browse.php?beginner=1" title="Beginner Friendly Disc Golf Courses">Beginner Friendly Disc Golf Courses</a></li>
# <li><a href="/help/" title="Help / FAQ">Help / FAQ</a></li>
# <li><a href="/store" title="API">API</a></li>
# <li><a data-xf-click="overlay" href="/misc/contact" title="Contact us">Contact us</a></li>
# <li><a href="/forums/-/index.rss" target="_blank" title="RSS"><span aria-hidden="true"><i aria-hidden="true" class="fa--xf far fa-rss"></i><span class="u-srOnly">RSS</span></span></a></li>
# </ul>
# <div class="c-footer-links">
# <div class="c-footer-icons">
# <a class="c-footer-follow fb" href="https://facebook.com/discgolfcoursereview" rel="noreferrer" target="_blank" title="DGCourseReview on Facebook"></a>
# <a class="c-footer-follow tw" href="https://www.twitter.com/dgcoursereview" rel="noreferrer" target="_blank" title="DGCourseReview on Twitter"></a>
# <a class="c-footer-follow in" href="https://instagram.com/dgcoursereview" rel="noreferrer" target="_blank" title="DGCourseReview on Instagram"></a>
# <a class="c-footer-app ios" href="https://itunes.apple.com/us/app/disc-golf-course-review/id1029793833?ls=1&amp;mt=8" rel="noreferrer" target="_blank" title="Download DGCourseReview on the app store"><img alt="Download DGCourseReview on the app store" src="https://cdn2.imagearchive.com/imagearchive/data/assets/2024-02/1706822534_app-store-badge.png"/></a>
# <a class="c-footer-app play" href="https://play.google.com/store/apps/details?id=com.dgcoursereview.android" rel="noreferrer" target="_blank" title="Get DGCourseReview on Google Play"><img alt="Get DGCourseReview on Google Play" src="https://cdn2.imagearchive.com/imagearchive/data/assets/2024-02/1706822554_google-play-badge.png"/></a>
# </div>
# </div>
# </div>
# <div class="c-footer-courses">
# <ul>
# <li><a href="/unitedstates" title="Disc Golf Courses in the United States">Disc Golf Courses in the United States</a></li>
# <li><a href="/alabama" title="Disc Golf Courses in Alabama">Alabama</a></li>
# <li><a href="/alaska" title="Disc Golf Courses in Alaska">Alaska</a></li>
# <li><a href="/arizona" title="Disc Golf Courses in Arizona">Arizona</a></li>
# <li><a href="/arkansas" title="Disc Golf Courses in Arkansas">Arkansas</a></li>
# <li><a href="/california" title="Disc Golf Courses in California">California</a></li>
# <li><a href="/colorado" title="Disc Golf Courses in Colorado">Colorado</a></li>
# <li><a href="/connecticut" title="Disc Golf Courses in Connecticut">Connecticut</a></li>
# <li><a href="/delaware" title="Disc Golf Courses in Delaware">Delaware</a></li>
# <li><a href="/florida" title="Disc Golf Courses in Florida">Florida</a></li>
# <li><a href="/georgia" title="Disc Golf Courses in Georgia">Georgia</a></li>
# <li><a href="/hawaii" title="Disc Golf Courses in Hawaii">Hawaii</a></li>
# ...
#
#         // style plans
#         const annual = $('.formRow-label:contains("DGCR Premium Membership")').closest('.formRow--button');
#         if (annual.length) {
#             annual.addClass('gb-up-plan gb-up-annual');
#             annual.prepend('<h2>Annual</h2><h3>DGCR Premium Membership</h3><div class="gb-up-ribbon"><span>Most Popular</span></div>');
#         }
#
#         // move plan benefits
#         const overview = $('.formRow-explain', annual).detach();
#         $('.p-body-pageContent > .block').first().prepend(overview);
#
#         // if more than one payment option, show a form
#         if( $('select[name="payment_profile_id"]').length) {
#             $('.gb-up-plan dd').addClass('gb-up-collapsible');
#             $('.gb-up-plan dt').append(`<span class="gb-up-choose"></span>`);
#             $('.p-body-pageContent > .block .formRow--button dd').prepend('<span class="gb-up-buttons-label">Payment method:</span><div class="gb-up-buttons"><div class="gb-up-button gb-up-button-cc">Stripe</div><div class="gb-up-button gb-up-button-pp">PayPal</div></div>');
#             $('.formRow--button').find('select option:contains("Credit")').attr('selected', true);
#             $('.gb-up-button-cc').addClass('selected');
#             $(document).on('click', '.gb-up-choose', showForm);
#             $(document).on('click', '.gb-up-button-cc', selectCC);
#             $(document).on('click', '.gb-up-button-pp', selectPP);
#             function showForm() {
#                 $('.gb-up-choose.active').not(this).removeClass('active').closest('dt').siblings('dd').slideToggle();
#                 const button = $(this);
#                 button.closest('dt').siblings('dd').slideToggle();
#                 button.toggleClass('active');
#             }
#             function selectCC() {
#                 let option = $(this);
#                 option.siblings('.gb-up-button').removeClass('selected');
#                 option.addClass('selected');
#                 option.closest('dd').find('select option:contains("PayPal")').attr('selected', false);
#                 option.closest('dd').find('select option:contains("Credit")').attr('selected', true);
#             }
#             function selectPP() {
#                 let option = $(this);
#                 option.siblings('.gb-up-button').removeClass('selected');
#                 option.addClass('selected');
#                 option.closest('dd').find('select option:contains("Credit")').attr('selected', false);
#                 option.closest('dd').find('select option:contains("PayPal")').attr('selected', true);
#             }
#         }
#     }
#
# 	// responsive table
#
# 	// sets cell labels and min-width for mobile support and cohesive layout
#     // sets cell labels and min-width for mobile support and cohesive layout
#     function responsiveTableSetup(table) {
#         console.log('Setting labels');
#
#         // copy th content into an array
#         let th = [];
#         $('thead tr th', table).each(function() {
#             let title;
#
#             if ( $('._sort', this).length ) {
#                 console.log('th has sort');
#                 //title = $('._sort', this).html;
#
#                 title = $('._sort', this).clone();
#                 console.log(`title 1: ${title}`);
#                 title.find('.sort_caret').remove();
#                 title.find('i').remove();
#                 console.log(`title 2: ${title}`);
#
#                 th.push(title.html());
#
#             } else {
#                 console.log('regular th');
#
#                 th.push($(this).html());
#             }
#
#             //th.push(title.html());
#             //th.push($(this).html());
#         });
#
#         console.log(th);
#
#         let firstRow = false;
#         let tdWidth = [];
#         const hasSections = $('._section', table).length ? true : false;
#
#         $('tbody tr', table).each(function(i) {
#             const row = $(this);
#             const isSection = row.hasClass('_section') ? true : false;
#
#             if ( hasSections ) {
#                 firstRow = (i == 1) ? true : false;
#             } else {
#                 firstRow = (i == 0) ? true : false;
#             }
#
#             $('> td', row).each(function(i) {
#                 const td = $(this);
#
#                 // save width into an array
#                 if ( firstRow ) {
#                     console.log('first row - collecting width');
#                     tdWidth.push(td.outerWidth());
#                 }
#
#                 if ( isSection || typeof td.attr('colspan') !== 'undefined' ) {
#
#                     // set td to max-width
#                     td.css('min-width','100%');
#
#                 } else {
#
#                     // set td min-width
#                     td.css('min-width',tdWidth[i]);
#
#                     // append labels
#                     if (typeof td.data('label') !== 'undefined') {
#
#                         if ( td.data('label') ) {
#                             td.prepend(`<span class="_mobile_label">${td.data('label')}</span>`);
#                         }
#                     } else {
#                         td.prepend(`<span class="_mobile_label">${th[i]}</span>`);
#                     }
#                 }
#             });
#         });
#
#         console.log(tdWidth);
#         table.addClass('_mobile_ready');
#     }
#
#     function responsiveTable() {
#         $('.c-table._responsive').each(function() {
#
#             const table = $(this);
#             const wrapper = table.closest('.c-table-wrapper');
#             table.removeClass('_mobile').removeClass('_collapsed');
#
#             if ( !(table.hasClass('_collapsible') && !(table.hasClass('_active'))) ) {
#
#                 if ( wrapper.width() < table.width() ) {
#
#                     if ( !(table.hasClass('_collapsed')) ) {
#
#                         console.log('collapse table');
#
#                         table.hasClass('_mobile_ready') ? console.log('skipping mobile prep') : responsiveTableSetup(table);
#                         table.addClass('_mobile');
#                         table.addClass('_collapsed');
#                     } else {
#                         console.log('table already collapsed, skipping');
#                     }
#
#                 } else {
#                     table.removeClass('_collapsed');
#                     console.log('regular table');
#                 }
#             } else {
#                 console.log('table collapsed - skipping');
#             }
#
#         });
#     }
#
#     $(window).bind("load", function() {
#         console.log('check tables');
#
#         $(window).on("resize", function () {
#             responsiveTable();
#         }).resize();
#
#     });
#
#     $(document).on('click', '.button[data-xf-click="overlay"]', function () {
#         responsiveTable();
#     });
#
#     $(document).on('click', '.tee_stats_switch', function () {
#         responsiveTable();
#     });
#
#
# </script>
# <script>
# 		$(document).on('xf:reinit',function(e,i){ $(i).children('.overlay[data-url]').each(function(){gtag('event','page_view',{page_title:$(this).find('.overlay-title').text(),page_location:$(this).data('url')});});});$(".file-preview").on("click",function(){gtag('event','file_download',{link_url:(new URL($(this).attr("href"),window.location.origin)).href,file_name:$(this).parent().find('.file-name').text()})});$('.shareButtons-button').on('click',function(){gtag('event','share',{method:$(this).attr('class').match(/.*shareButtons-button--(.*?)$|\s/)[1]});});$('.bookmarkLink:not(.is-bookmarked)').on('click',function(){gtag('event','bookmark');});$(window).on('beforeinstallprompt',function(){gtag("event","app_install_prompt");});$(window).on('appinstalled',function(){gtag("event","app_install");});XF.PWA&&XF.PWA.isRunning()&&document.addEventListener("visibilitychange",function(){"visible"===document.visibilityState&&gtag("event","app_open")});
# 		jQuery.extend(true, XF.config, {
# 			//
# 			userId: 0,
# 			enablePush: true,
# 			pushAppServerKey: 'BJsYmJtL31bESF44lvGrvRirqd3oHfr1pAToxm0l1CEyszIfDD9J7R_dfu4jjIc-1U14sFr_uYM8PJ6f-O_h1cE',
# 			url: {
# 				fullBase: 'https://www.dgcoursereview.com/',
# 				basePath: '/',
# 				css: '/css.php?css=__SENTINEL__&s=2&l=1&d=1723568136',
# 				keepAlive: '/login/keep-alive'
# 			},
# 			cookie: {
# 				path: '/',
# 				domain: '',
# 				prefix: 'xf_',
# 				secure: true,
# 				consentMode: 'disabled',
# 				consented: ["optional","_third_party"]
# 			},
# 			cacheKey: 'ad1b06fc68c5c21b871fea8315bbc570',
# 			csrf: '1723640587,3413215958cc2229644f25dedc5fbf42',
# 			js: {"\/js\/dg\/course_view.min.js?_v=32f1f1e5":true,"\/js\/xf\/lightbox-compiled.js?_v=32f1f1e5":true,"\/js\/dg\/course_main.min.js?_v=32f1f1e5":true,"\/js\/dg\/user_location.min.js?_v=32f1f1e5":true,"https:\/\/btloader.com\/tag?o=5698917485248512&upapi=true&domain=dgcoursereview.com":true,"\/js\/xf\/notice.min.js?_v=32f1f1e5":true,"\/js\/GoogleOneTap\/login.min.js?_v=32f1f1e5":true},
# 			css: {"public:lightbox.less":true,"public:notices.less":true,"public:sponsor.less":true,"public:extra.less":true},
# 			time: {
# 				now: 1723640587,
# 				today: 1723608000,
# 				todayDow: 3,
# 				tomorrow: 1723694400,
# 				yesterday: 1723521600,
# 				week: 1723089600
# 			},
# 			borderSizeFeature: '3px',
# 			fontAwesomeWeight: 'r',
# 			enableRtnProtect: true,
#
# 			enableFormSubmitSticky: true,
# 			uploadMaxFilesize: 536870912,
# 			allowedVideoExtensions: ["m4v","mov","mp4","mp4v","mpeg","mpg","ogv","webm"],
# 			allowedAudioExtensions: ["mp3","opus","ogg","wav"],
# 			shortcodeToEmoji: true,
# 			visitorCounts: {
# 				conversations_unread: '0',
# 				alerts_unviewed: '0',
# 				total_unread: '0',
# 				title_count: true,
# 				icon_indicator: true
# 			},
# 			jsState: {},
# 			publicMetadataLogoUrl: '',
# 			publicPushBadgeUrl: 'https://www.dgcoursereview.com/styles/default/xenforo/bell.png'
# 		});
#
# 		jQuery.extend(XF.phrases, {
# 			//
# 			date_x_at_time_y: "{date} at {time}",
# 			day_x_at_time_y:  "{day} at {time}",
# 			yesterday_at_x:   "Yesterday at {time}",
# 			x_minutes_ago:    "{minutes} minutes ago",
# 			one_minute_ago:   "1 minute ago",
# 			a_moment_ago:     "A moment ago",
# 			today_at_x:       "Today at {time}",
# 			in_a_moment:      "In a moment",
# 			in_a_minute:      "In a minute",
# 			in_x_minutes:     "In {minutes} minutes",
# 			later_today_at_x: "Later today at {time}",
# 			tomorrow_at_x:    "Tomorrow at {time}",
#
# 			day0: "Sunday",
# 			day1: "Monday",
# 			day2: "Tuesday",
# 			day3: "Wednesday",
# 			day4: "Thursday",
# 			day5: "Friday",
# 			day6: "Saturday",
#
# 			dayShort0: "Sun",
# 			dayShort1: "Mon",
# 			dayShort2: "Tue",
# 			dayShort3: "Wed",
# 			dayShort4: "Thu",
# 			dayShort5: "Fri",
# 			dayShort6: "Sat",
#
# 			month0: "January",
# 			month1: "February",
# 			month2: "March",
# 			month3: "April",
# 			month4: "May",
# 			month5: "June",
# 			month6: "July",
# 			month7: "August",
# 			month8: "September",
# 			month9: "October",
# 			month10: "November",
# 			month11: "December",
#
# 			active_user_changed_reload_page: "The active user has changed. Reload the page for the latest version.",
# 			server_did_not_respond_in_time_try_again: "The server did not respond in time. Please try again.",
# 			oops_we_ran_into_some_problems: "Oops! We ran into some problems.",
# 			oops_we_ran_into_some_problems_more_details_console: "Oops! We ran into some problems. Please try again later. More error details may be in the browser console.",
# 			file_too_large_to_upload: "The file is too large to be uploaded.",
# 			uploaded_file_is_too_large_for_server_to_process: "The uploaded file is too large for the server to process.",
# 			files_being_uploaded_are_you_sure: "Files are still being uploaded. Are you sure you want to submit this form?",
# 			attach: "Attach files",
# 			rich_text_box: "Rich text box",
# 			close: "Close",
# 			link_copied_to_clipboard: "Link copied to clipboard.",
# 			text_copied_to_clipboard: "Text copied to clipboard.",
# 			loading: "Loading…",
# 			you_have_exceeded_maximum_number_of_selectable_items: "You have exceeded the maximum number of selectable items.",
#
# 			processing: "Processing",
# 			'processing...': "Processing…",
#
# 			showing_x_of_y_items: "Showing {count} of {total} items",
# 			showing_all_items: "Showing all items",
# 			no_items_to_display: "No items to display",
#
# 			number_button_up: "Increase",
# 			number_button_down: "Decrease",
#
# 			push_enable_notification_title: "Push notifications enabled successfully at Disc Golf Course Review",
# 			push_enable_notification_body: "Thank you for enabling push notifications!",
#
# 			pull_down_to_refresh: "Pull down to refresh",
# 			release_to_refresh: "Release to refresh",
# 			refreshing: "Refreshing…"
# 		,
# 			"svStandardLib_time.day": "{count} day",
# 			"svStandardLib_time.days": "{count} days",
# 			"svStandardLib_time.hour": "{count} hour",
# 			"svStandardLib_time.hours": "{count} hours",
# 			"svStandardLib_time.minute": "{count} minutes",
# 			"svStandardLib_time.minutes": "{count} minutes",
# 			"svStandardLib_time.month": "{count} month",
# 			"svStandardLib_time.months": "{count} months",
# 			"svStandardLib_time.second": "{count} second",
# 			"svStandardLib_time.seconds": "{count} seconds",
# 			"svStandardLib_time.week": "time.week",
# 			"svStandardLib_time.weeks": "{count} weeks",
# 			"svStandardLib_time.year": "{count} year",
# 			"svStandardLib_time.years": "{count} years"
#
# 		});
# 	</script>
# <form hidden="hidden" style="display:none">
# <input id="_xfClientLoadTime" name="_xfClientLoadTime" tabindex="-1" title="_xfClientLoadTime" type="text" value=""/>
# </form>
# <script type="application/ld+json">
#         {
#     "@context": "https://schema.org",
#     "@type": "SportsActivityLocation",
#     "name": "Prompton State Park",
#     "@id": "https://www.dgcoursereview.com/courses/prompton-state-park.1",
#     "description": "A very scenic, mostly open course overlooking Prompton Lake with considerable elevation changes.  Each hole has 2 baskets, yellows are short, reds are long. The lake comes into play on three holes as well.",
#     "isAccessibleForFree": true,
#     "url": "https://www.dgcoursereview.com/courses/prompton-state-park.1",
#     "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "[unknown]",
#         "addressLocality": "Honesdale",
#         "addressRegion": "Pennsylvania",
#         "postalCode": "18456",
#         "addressCountry": "United States"
#     },
#     "geo": {
#         "@type": "GeoCoordinates",
#         "latitude": 41.591367,
#         "longitude": -75.330167
#     },
#     "hasMap": "https://www.google.com/maps/search/?api=1&query=41.591367,-75.330167",
#     "image": "https://cdn.dgcoursereview.com/data/attach/77/77581-74568552.jpg",
#     "aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": 3.95,
#         "bestRating": 5,
#         "worstRating": 0,
#         "ratingCount": 20
#     },
#     "photo": {
#         "@type": "WebPage",
#         "name": "Prompton State Park Gallery",
#         "url": "https://www.dgcoursereview.com/courses/prompton-state-park.1/media"
#     },
#     "amenityFeature": [
#         {
#             "@type": "LocationFeatureSpecification",
#             "name": "Disc golf course",
#             "value": "true"
#         },
#         {
#             "@type": "LocationFeatureSpecification",
#             "name": "Camping",
#             "value": "true"
#         },
#         {
#             "@type": "LocationFeatureSpecification",
#             "name": "Pet-Friendly",
#             "value": "true"
#         },
#         {
#             "@type": "LocationFeatureSpecification",
#             "name": "Restrooms",
#             "value": "false"
#         },
#         {
#             "@type": "LocationFeatureSpecification",
#             "name": "On ball golf",
#             "value": "false"
#         },
#         {
#             "@type": "LocationFeatureSpecification",
#             "name": "Cart-Friendly",
#             "value": "true"
#         }
#     ]
# }
#     </script>
# <script async="" defer="" src="https://accounts.google.com/gsi/client"></script>
# <div data-callback="handleGOTResponse" data-client_id="1020943931061-p5d87qod3kt86p2t01k1l6ak8re88q7k.apps.googleusercontent.com" data-nonce="" data-xf_callback_uri="https://www.dgcoursereview.com/login/got-verify" id="g_id_onload">
# </div>
# </body>
# </html>

# %%
soup.find(property = ['og:'+'description']).get('content')
# Out:
# 'A very scenic, mostly open course overlooking Prompton Lake with considerable elevation changes.  Each hole has 2 baskets, yellows are short, reds are long. The lake comes into play on three holes as well.'

# %%
# A bunch of useful information is contained in the block of type 'application/ld+json'
dict=json.loads(soup.find('script', type="application/ld+json").text)
print(dict)
# Out:
# {'@context': 'https://schema.org', '@type': 'SportsActivityLocation', 'name': 'Prompton State Park', '@id': 'https://www.dgcoursereview.com/courses/prompton-state-park.1', 'description': 'A very scenic, mostly open course overlooking Prompton Lake with considerable elevation changes.  Each hole has 2 baskets, yellows are short, reds are long. The lake comes into play on three holes as well.', 'isAccessibleForFree': True, 'url': 'https://www.dgcoursereview.com/courses/prompton-state-park.1', 'address': {'@type': 'PostalAddress', 'streetAddress': '[unknown]', 'addressLocality': 'Honesdale', 'addressRegion': 'Pennsylvania', 'postalCode': '18456', 'addressCountry': 'United States'}, 'geo': {'@type': 'GeoCoordinates', 'latitude': 41.591367, 'longitude': -75.330167}, 'hasMap': 'https://www.google.com/maps/search/?api=1&query=41.591367,-75.330167', 'image': 'https://cdn.dgcoursereview.com/data/attach/77/77581-74568552.jpg', 'aggregateRating': {'@type': 'AggregateRating', 'ratingValue': 3.95, 'bestRating': 5, 'worstRating': 0, 'ratingCount': 20}, 'photo': {'@type': 'WebPage', 'name': 'Prompton State Park Gallery', 'url': 'https://www.dgcoursereview.com/courses/prompton-state-park.1/media'}, 'amenityFeature': [{'@type': 'LocationFeatureSpecification', 'name': 'Disc golf course', 'value': 'true'}, {'@type': 'LocationFeatureSpecification', 'name': 'Camping', 'value': 'true'}, {'@type': 'LocationFeatureSpecification', 'name': 'Pet-Friendly', 'value': 'true'}, {'@type': 'LocationFeatureSpecification', 'name': 'Restrooms', 'value': 'false'}, {'@type': 'LocationFeatureSpecification', 'name': 'On ball golf', 'value': 'false'}, {'@type': 'LocationFeatureSpecification', 'name': 'Cart-Friendly', 'value': 'true'}]}

# %%
dict['name']
# Out:
# 'Prompton State Park'

# %%
soup.find('script', type="application/ld+json").text
# Out:
# '\n        {\n    "@context": "https://schema.org",\n    "@type": "SportsActivityLocation",\n    "name": "Prompton State Park",\n    "@id": "https://www.dgcoursereview.com/courses/prompton-state-park.1",\n    "description": "A very scenic, mostly open course overlooking Prompton Lake with considerable elevation changes.  Each hole has 2 baskets, yellows are short, reds are long. The lake comes into play on three holes as well.",\n    "isAccessibleForFree": true,\n    "url": "https://www.dgcoursereview.com/courses/prompton-state-park.1",\n    "address": {\n        "@type": "PostalAddress",\n        "streetAddress": "[unknown]",\n        "addressLocality": "Honesdale",\n        "addressRegion": "Pennsylvania",\n        "postalCode": "18456",\n        "addressCountry": "United States"\n    },\n    "geo": {\n        "@type": "GeoCoordinates",\n        "latitude": 41.591367,\n        "longitude": -75.330167\n    },\n    "hasMap": "https://www.google.com/maps/search/?api=1&query=41.591367,-75.330167",\n    "image": "https://cdn.dgcoursereview.com/data/attach/77/77581-74568552.jpg",\n    "aggregateRating": {\n        "@type": "AggregateRating",\n        "ratingValue": 3.95,\n        "bestRating": 5,\n        "worstRating": 0,\n        "ratingCount": 20\n    },\n    "photo": {\n        "@type": "WebPage",\n        "name": "Prompton State Park Gallery",\n        "url": "https://www.dgcoursereview.com/courses/prompton-state-park.1/media"\n    },\n    "amenityFeature": [\n        {\n            "@type": "LocationFeatureSpecification",\n            "name": "Disc golf course",\n            "value": "true"\n        },\n        {\n            "@type": "LocationFeatureSpecification",\n            "name": "Camping",\n            "value": "true"\n        },\n        {\n            "@type": "LocationFeatureSpecification",\n            "name": "Pet-Friendly",\n            "value": "true"\n        },\n        {\n            "@type": "LocationFeatureSpecification",\n            "name": "Restrooms",\n            "value": "false"\n        },\n        {\n            "@type": "LocationFeatureSpecification",\n            "name": "On ball golf",\n            "value": "false"\n        },\n        {\n            "@type": "LocationFeatureSpecification",\n            "name": "Cart-Friendly",\n            "value": "true"\n        }\n    ]\n}\n    '

# %%
soup.find(string='Holes').find_parent().find_previous().text
# Out:
# '\nHoles\n'

# %%
soup.find(string = re.compile('Designer')).find_parent().find_next().text
# Out:
# 'John Harvey Dave Harvey'

# %%
soup.find(string = re.compile('Water in play')).find_parent().find_previous().text
# Out:
# '5'

# %%
soup.find(string=re.compile('Par Info')).find_parent().next_sibling
# Out:
# '\n'

# %%
D = soup.find_all('div', class_ = 'c-course-details-row')

# %%
D[4].text
# Out:
# '\nDGCR SSE: [ ? ]\n\n\n\n46.8\n\n\n\n54.3\n\n\n'

# %%
soup.find(string = re.compile('Par Info')).find_parent().find_parent()
# Out:
# <div class="c-course-details-row">
# <span>Par Info:</span>
# <span>
# <span class="c-bullet">
# <span class="c-bullet-icon" style="background-color:#FFFF00;"></span>
# 57
# </span>
# <span class="c-bullet">
# <span class="c-bullet-icon" style="background-color:#FF0000;"></span>
# 67
# </span>
# </span>
# </div>

# %%
C=soup.find_all('div', class_='c-course-details-row')

# %%
A = soup.find_all(class_='c-course-details-row', string=re.compile('DGCR'))

# %%
S = soup.find(string=re.compile('SSE')).find_parent().find_parent().find_all(class_="c-bullet")

q = []
for s in S:
    q.append(s.text.strip())

# %%
q
# Out:
# ['46.8', '54.3']

# %%
#soup.find('h3', string="Course conditions:").find_parent().find(class_='active').text

# %%
for s in soup.find_all(class_="c-course-stat"):
    print(s.text)
# Out:
# 5864 ft. - 8071 ft. Metric
#
#
# Moderately Hilly
#
#
# Lightly Wooded
#
#
# 18
# Holes
#
#
# 18
# Baskets
#
#
# 5
# Water in play

# %%
soup.find(class_='c-course-stat-label', string='Holes').find_previous().text
# Out:
# '18'

# %%
soup.find(class_='c-course-stat-label', string='Water in play')
# Out:
# <span class="c-course-stat-label">Water in play</span>

# %%
soup.find(class_='c-course-stat-label', string='Water in play').find_previous().text
# Out:
# '5'

# %%
# Scrape length
S = soup.find_all(class_="dg_unit")
for s in S:
    print(s['data-meters'])
# Out:
# 1787
# 2460

# %%
# Woods
[v.text.strip() for v in soup.find(class_="c-course-course_info").find_all(class_="c-course-stat")]
# Out:
# ['5864 ft.\xa0-\xa08071 ft. Metric',
#  'Moderately Hilly',
#  'Lightly Wooded',
#  '18\nHoles',
#  '18\nBaskets',
#  '5\nWater in play']

# %%
# Rounds recorded\
Q = []
for s in soup.find(string=re.compile('Rounds Recorded')).find_parent().find_next():
    Q.append(s.text.strip())

# %%
[s.text.strip() for s in soup.find(string=re.compile('Rounds Recorded')).find_parent().find_next()]
# Out:
# ['', '101 / 62', '', '77 / 60', '', '20 / 67', '']

# %%
for s in soup.find_all(class_='fas fa-link'):
    print(s.find_parent()['href'])
# Out:
# http://www.dcnr.state.pa.us/stateparks/findapark/prompton/index.htm

# %%
links = []
for tag in soup.find_all(class_='fas fa-link'):
    links.append(tag.find_parent()['href'])

# %%
links
# Out:
# ['http://www.dcnr.state.pa.us/stateparks/findapark/prompton/index.htm']

# %%
[tag.find_parent()['href'] for tag in soup.find_all(class_='fas fa-link')]
# Out:
# ['http://www.dcnr.state.pa.us/stateparks/findapark/prompton/index.htm']

# %%
len(soup.find_all(class_='c-course _extinct'))
# Out:
# 0

# %%
Q = soup.find(string='Rounds Recorded / Average Score:').find_parent().find_next()

# %%
print(Q)
# Out:
# <span>
# <a href="/courses/prompton-state-park.1/rounds">101 / 62</a>
# <span class="c-bullet"><span class="c-bullet-icon" style="background-color:#FFFF00;"></span>77 / 60</span>
# <span class="c-bullet"><span class="c-bullet-icon" style="background-color:#FF0000;"></span>20 / 67</span>
# </span>

# %%
Q.find('a').text
# Out:
# '101 / 62'

# %%
d = {}
for q in Q.find_all(class_="c-bullet"):
    color = q.next_element['style'].split(':')[-1][:-1]
    roundsandavg = q.text
    d[color] = roundsandavg

# %%
d
# Out:
# {'#FFFF00': '77 / 60', '#FF0000': '20 / 67'}
