# %%
import pandas as pd
pd.set_option('display.max_columns', 200)

import matplotlib.pyplot as plt
plt.style.use('bmh') # available styles `plt.style.available` including ggplot

import seaborn as sns

import numpy as np

# %load_ext autoreload
# %autoreload 2

import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_pickle("../data/interim/database-2024-08-22-interim.pkl")

# %%
df.shape
# Out:
# (13918, 40)

# %%
df.head()
# Out:
#                                               url                       name  \
# 1  https://www.dgcoursereview.com/course.php?id=1        Prompton State Park
# 2  https://www.dgcoursereview.com/course.php?id=2  Ellison Park - Old Layout
# 3  https://www.dgcoursereview.com/course.php?id=3                  Chili DGC
# 4  https://www.dgcoursereview.com/course.php?id=4           Churchville Park
# 5  https://www.dgcoursereview.com/course.php?id=5                Sawyer Park
#
#                                          description  is_free  \
# 1  A very scenic, mostly open course overlooking ...     True
# 2  The Ellison Park Disc Golf Course is located o...     True
# 3  Located southwest of Rochester N.Y. in the Tow...     True
# 4  Located west of Rochester N.Y. in the town of ...     True
# 5  Small scenic park with creek running throughou...     True
#
#    year_established  tee_type      basket_type  \
# 1              1997  Concrete       DISCatcher
# 2              1989    Rubber           Mach 3
# 3              1995  Concrete  Dynamic Veteran
# 4              2003    Rubber       DISCatcher
# 5              2006      Dirt       DISCatcher
#
#                                           designer  water_in_play  \
# 1                          John Harvey Dave Harvey              5
# 2  Royce Racinowski, Jim Palmeri &amp; Jamie Moldt           <NA>
# 3                                             None              6
# 4                                             None              1
# 5                                             None              3
#
#    basket_number  number_of_holes               sse           par  \
# 1             18               18      [46.8, 54.3]      [57, 67]
# 2             18               18            [52.5]          [57]
# 3             18               18  [43, 48.9, 55.9]  [57, 58, 58]
# 4             19               19        [44, 47.3]      [65, 60]
# 5              9                9            [20.5]          [27]
#
#    course_condition length_metric length_imperial           terrain  \
# 1               NaN  [1787, 2460]    [5864, 8071]  Moderately Hilly
# 2               NaN        [1900]          [6234]        Very Hilly
# 3               5.0  [1211, 2147]    [3973, 7045]       Mostly Flat
# 4               4.0  [1344, 1614]    [4408, 5296]       Mostly Flat
# 5               NaN    [576, 642]    [1890, 2105]       Mostly Flat
#
#                woods                                              links  \
# 1     Lightly Wooded  [http://www.dcnr.state.pa.us/stateparks/findap...
# 2  Moderately Wooded  [http://www.discgolfrochester.com, http://www....
# 3     Lightly Wooded  [http://www.discgolfrochester.com, http://nefa...
# 4     Lightly Wooded  [http://www.discgolfrochester.com, https://map...
# 5     Heavily Wooded  [http://www.discgolfrochester.com, http://nefa...
#
#                                     local_directions  \
# 1  From I-81, take Rte. 6 east, from I-84, take R...
# 2  From I-490 south of Rochester, exit north on H...
# 3  I-490 to Exit 5, Chili Center, Rte. 386 south ...
# 4  Take I-490 E/W to Churchville exit (Exit 3). T...
# 5  Rte. 490 to Rte. 390 N. Exit Vintage Ln., turn...
#
#                      Rounds Recorded & Average Score course_type  \
# 1  {'Total': '101 / 62', '#FFFF00': '77 / 60', '#...   Permanent
# 2       {'Total': '417 / 63', '#0000CC': '383 / 63'}    Seasonal
# 3  {'Total': '789 / 70', '#0000CC': '20 / 70', '#...   Permanent
# 4  {'Total': '216 / 64', '#0000CC': '13 / 65', '#...    Seasonal
# 5         {'Total': '64 / 28', '#FFFFFF': '53 / 27'}   Permanent
#
#               street_address         town        region postal_code  \
# 1                  [unknown]    Honesdale  Pennsylvania       18456
# 2                  [unknown]    Rochester      New York       14610
# 3  400 Scottsville Chili Rd.        Chili      New York       14428
# 4                  [unknown]  Churchville      New York       14428
# 5                  [unknown]       Greece      New York       14616
#
#          country   latitude  longitude  rating_mean  rating_max  rating_min  \
# 1  United States  41.591367 -75.330167         3.95         5.0         0.0
# 2  United States  43.153154 -77.527428         3.47         5.0         0.0
# 3  United States  43.077770 -77.766098         3.90         5.0         0.0
# 4  United States  43.113819 -77.883698         2.57         5.0         0.0
# 5  United States  43.248798 -77.693089         1.98         5.0         0.0
#
#    rating_count  has_camping  is_pet_friendly  has_restrooms  \
# 1            20         True             True          False
# 2            54        False             True          False
# 3            70        False             True           True
# 4            21        False             True           True
# 5            30        False             True          False
#
#    on_ball_golf_course  is_cart_friendly  has_multiple_tees  has_multiple_pins
# 1                False              True              False               True
# 2                False             False              False              False
# 3                False              True               True              False
# 4                False              True               True              False
# 5                False              True              False              False

# %%
df['course_type'].value_counts()
# Out:
# course_type
# Permanent    13104
# Seasonal       515
# Temporary      299
# Name: count, dtype: int64

# %%
sns.countplot(df['year_established'])
plt.show()
