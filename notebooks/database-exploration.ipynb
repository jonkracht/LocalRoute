# %%
import json

# %%
f = open('../data/raw/database.json')
data = json.load(f)

# %%
data
# Out:
# {'1': {'url': 'https://www.dgcoursereview.com/course.php?id=1',
#   'name': 'Prompton State Park',
#   'description': 'A very scenic, mostly open course overlooking Prompton Lake with considerable elevation changes.  Each hole has 2 baskets, yellows are short, reds are long. The lake comes into play on three holes as well.',
#   'isAccessibleForFree': True,
#   'address': {'@type': 'PostalAddress',
#    'streetAddress': '[unknown]',
#    'addressLocality': 'Honesdale',
#    'addressRegion': 'Pennsylvania',
#    'postalCode': '18456',
#    'addressCountry': 'United States'},
#   'geo': {'@type': 'GeoCoordinates',
#    'latitude': 41.591367,
#    'longitude': -75.330167},
#   'aggregateRating': {'@type': 'AggregateRating',
#    'ratingValue': 3.95,
#    'bestRating': 5,
#    'worstRating': 0,
#    'ratingCount': 20},
#   'amenityFeature': [{'@type': 'LocationFeatureSpecification',
#     'name': 'Disc golf course',
#     'value': 'true'},
#    {'@type': 'LocationFeatureSpecification',
# ...

# %%
data['34']
# Out:
# {'url': 'https://www.dgcoursereview.com/course.php?id=34',
#  'name': 'Lawrence Park',
#  'description': 'Newly renovated, same layout, but now with 18 baskets and full concrete teepads.  Hole 1 begins at the base of the large hill, near the parking lot furthest back.  See kiosk near large pavilion for course map and info.',
#  'isAccessibleForFree': True,
#  'address': {'@type': 'PostalAddress',
#   'streetAddress': '[unknown]',
#   'addressLocality': 'Kalispell',
#   'addressRegion': 'Montana',
#   'postalCode': '59901',
#   'addressCountry': 'United States'},
#  'geo': {'@type': 'GeoCoordinates',
#   'latitude': 48.20982,
#   'longitude': -114.313797},
#  'aggregateRating': {'@type': 'AggregateRating',
#   'ratingValue': 2.77,
#   'bestRating': 5,
#   'worstRating': 0,
#   'ratingCount': 11},
#  'amenityFeature': [{'@type': 'LocationFeatureSpecification',
#    'name': 'Disc golf course',
#    'value': 'true'},
#   {'@type': 'LocationFeatureSpecification',
#    'name': 'Camping',
# ...

# %%
data['3']['description']
# Out:
# 'Located southwest of Rochester N.Y. in the Town of Chili. A beautiful links style course built on old Baker Farm. Features include several elevated tees and greens, flower gardens, a creek and interesting obstacles such as a silo, an old windmill and woodchip piles that act as "inverted bunkers".'
